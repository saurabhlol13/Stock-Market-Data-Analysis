# %%
# For Data Processing

import pandas as pd
import numpy as np

# %%
# Data Visualization

import matplotlib.pyplot as plt
import seaborn as s
# %matplotlib inline

# %%
# For reading stock data from yahoo

import pandas_datareader as dr

# %%
# For time stamps

from datetime import datetime

# %% [markdown]
# # Fundamental Analytics
# In this section I'll go over how to handle requesting stock information with pandas, and how to analyze basic attributes of a stock.

# %%
# List of Tech_stocks for analytics

tech_list = ['AAPL','GOOGL','MSFT','AMZN']

# set up Start and End time for data grab

end = datetime.now()
start = datetime(end.year-5,end.month,end.day)

#Getting the data of pervious five years

for i in tech_list:
    globals()[i] = dr.data.get_data_yahoo(i,start,end)

# %% [markdown]
#
# Let's go ahead and play aorund with the AAPL(Apple) Stock DataFrame to get a feel for the data

# %%
#First 5 days data of AAPL(Apple) Stocks DataFrame

AAPL.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2014-06-18  92.290001  91.349998  92.269997  92.180000   33514000.0  84.485222
# 2014-06-19  92.300003  91.339996  92.290001  91.860001   35528000.0  84.191948
# 2014-06-20  92.550003  90.900002  91.849998  90.910004  100898000.0  83.321236
# 2014-06-23  91.620003  90.599998  91.320000  90.830002   43694000.0  83.247910
# 2014-06-24  91.739998  90.190002  90.750000  90.279999   39036000.0  82.743828

# %%
#Last 5 days data of AAPL(Apple) Stocks DataFrame

AAPL.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-06-12  195.970001  193.389999  193.949997  194.190002  18253200.0
# 2019-06-13  196.789993  193.600006  194.699997  194.149994  21674600.0
# 2019-06-14  193.589996  190.300003  191.550003  192.740005  18761500.0
# 2019-06-17  194.960007  192.169998  192.899994  193.889999  14669100.0
# 2019-06-18  200.289993  195.210007  196.050003  198.449997  26087900.0
#
#              Adj Close
# Date
# 2019-06-12  194.190002
# 2019-06-13  194.149994
# 2019-06-14  192.740005
# 2019-06-17  193.889999
# 2019-06-18  198.449997

# %%
#General Information Of AAPL Stocks DataFrame

AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2014-06-18 to 2019-06-18
# Data columns (total 6 columns):
# High         1259 non-null float64
# Low          1259 non-null float64
# Open         1259 non-null float64
# Close        1259 non-null float64
# Volume       1259 non-null float64
# Adj Close    1259 non-null float64
# dtypes: float64(6)
# memory usage: 68.9 KB

# %%
#Data types of APPLE Stocks DataFrame

AAPL.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
#Summary stats for Apple Stocks DataFrame

AAPL.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean    141.756140   139.276601   140.507196   140.556219  3.874825e+07
# std      36.737087    36.050793    36.370190    36.406731  1.925246e+07
# min      90.699997    89.470001    90.000000    90.279999  1.147590e+07
# 25%     111.255001   108.840000   110.040001   109.875000  2.568255e+07
# 50%     129.559998   128.050003   128.639999   128.699997  3.372100e+07
# 75%     172.595001   169.689995   171.114998   171.075005  4.672885e+07
# max     233.470001   229.779999   230.779999   232.070007  1.898463e+08
#
#          Adj Close
# count  1259.000000
# mean    135.572471
# std      38.196511
# min      82.743828
# 25%     103.781921
# 50%     119.849411
# 75%     168.304855
# max     229.392090

# %% [markdown]
# Now that we've seen the DataFrame, let's go ahead and plot out the volume and closing price of the AAPL(Apple) stocks

# %%
# Let's see a historical view of the closing price

AAPL['Close'].plot(legend=True,figsize=(10,4))

# %%
# Let's see a historical view of the opening price and closing price

AAPL[['Open','Close']].plot(legend=True,figsize=(15,5))

# %%
# Let's see a monthly view of the opening price and closing price 

AAPL.loc['2019-05-01':'2019-05-31',['Open','Close']].plot(figsize=(15,5))

# %%
# Now Let's the percentage change of closing price

AAPL['Close'].pct_change()
# Out:
# Date
# 2014-06-18         NaN
# 2014-06-19   -0.003471
# 2014-06-20   -0.010342
# 2014-06-23   -0.000880
# 2014-06-24   -0.006055
# 2014-06-25    0.000886
# 2014-06-26    0.005976
# 2014-06-27    0.011881
# 2014-06-30    0.010328
# 2014-07-01    0.006349
# 2014-07-02   -0.000428
# 2014-07-03    0.005884
# 2014-07-07    0.020632
# 2014-07-08   -0.006460
# 2014-07-09    0.000420
# 2014-07-10   -0.003669
# 2014-07-11    0.001894
# 2014-07-14    0.012917
# 2014-07-15   -0.011716
# 2014-07-16   -0.005665
# 2014-07-17   -0.017831
# 2014-07-18    0.014395
# 2014-07-21   -0.005189
# 2014-07-22    0.008303
# 2014-07-23    0.026077
# 2014-07-24   -0.001646
# 2014-07-25    0.006596
# 2014-07-28    0.013822
# 2014-07-29   -0.006463
# 2014-07-30   -0.002338
#                 ...
# 2019-05-07   -0.026957
# 2019-05-08    0.000197
# 2019-05-09   -0.010744
# 2019-05-10   -0.017637
# 2019-05-13   -0.058119
# 2019-05-14    0.015830
# 2019-05-15    0.011979
# 2019-05-16   -0.004400
# ...

# %%
# let's plot the percentage change in closing price everyday

AAPL['Close'].pct_change().plot(figsize=(15,5))

# %% [markdown]
# # Stock Trade By Volume
#
# Now that we've seen the DataFrame, let's go ahead and plot out the volume of the AAPL(Apple) stocks

# %%
# Now let's plot the total volume of stock being traded each day over the past year

AAPL['Volume'].plot(legend=True, figsize=(10,4))

# %% [markdown]
# # Daily Return Analysis

# %% [markdown]
# Now, that we've done some fundamental analysis, Let's go ahead and dive a little deeper.
#
# In order to do so, we need to take a closer look at the daily changes of the stock, and not just its absolute value. Let's go ahead and use pandas to retrieve the daily returns for the APPL stock

# %%
# We'll use pct_change to find the percent change for each day

AAPL['Daily Return'] = AAPL['Close'].pct_change()

# %%
# Lets plot the daily return percentage

AAPL['Daily Return'].plot(figsize=(15,5), legend=True, linestyle='--', marker='o')

# %%
# Only with histogram

AAPL['Daily Return'].hist(bins=100)

# %%
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn

s.distplot(AAPL['Daily Return'].dropna(), bins=100, color='magenta')
# Out:
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Grab all the closing prices for the tech stock list into one DataFrame

closingprice_df =dr.data.get_data_yahoo(tech_list, start, end)['Close']

# %%
# First ten days closing price of all companies

closingprice_df.head(10)
# Out:
# Symbols          AAPL        AMZN       GOOGL       MSFT
# Date
# 2014-06-18  92.180000  334.380005  560.659973  41.650002
# 2014-06-19  91.860001  327.000000  564.989990  41.509998
# 2014-06-20  90.910004  324.200012  566.520020  41.680000
# 2014-06-23  90.830002  327.239990  574.289978  41.990002
# 2014-06-24  90.279999  324.160004  572.539978  41.750000
# 2014-06-25  90.360001  327.440002  585.929993  42.029999
# 2014-06-26  90.900002  325.690002  584.770020  41.720001
# 2014-06-27  91.980003  324.570007  585.690002  42.250000
# 2014-06-30  92.930000  324.779999  584.669983  41.700001
# 2014-07-01  93.519997  332.390015  591.489990  41.869999

# %% [markdown]
# Now that we have all the closing prices, let's go ahead and get the daily return for all the stocks, like we did for the APPL stock.

# %%
# Make a new tech returns DataFrame

tech_returns = closingprice_df.pct_change()

# %%
# First 5 days percentage change of all companies

tech_returns.head()
# Out:
# Symbols         AAPL      AMZN     GOOGL      MSFT
# Date
# 2014-06-18       NaN       NaN       NaN       NaN
# 2014-06-19 -0.003471 -0.022071  0.007723 -0.003361
# 2014-06-20 -0.010342 -0.008563  0.002708  0.004095
# 2014-06-23 -0.000880  0.009377  0.013715  0.007438
# 2014-06-24 -0.006055 -0.009412 -0.003047 -0.005716

# %% [markdown]
# Now we can compare the daily percentage return of two stocks to check how correlated. First let's see a stock compared to itself.

# %%
# Comparing Google to itself should show a perfectly linear relationship

s.jointplot('GOOGL','GOOGL',tech_returns,kind='scatter',color='orange')
# Out:
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# So now we can see that if two stocks are perfectly (and positivley) correlated with each other a linear relationship bewteen its daily return values should occur.
#
# So let's go ahead and compare Google and Amazon the same way.

# %%
# We'll use joinplot to compare the daily returns of Google and Amazon.

s.jointplot('GOOGL','AMZN',tech_returns, kind='scatter',size=8, color='skyblue')
# Out:
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# With Hex plot

s.jointplot('GOOGL','AMZN',tech_returns, kind='hex',size=8, color='skyblue')
# Out:
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Lets check out for Apple and Microsoft with reg jointplot

s.jointplot('AAPL','MSFT',tech_returns, kind='reg', size=8, color='skyblue')
# Out:
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\M-HAMID\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Pair Plot
#
# Now, that we've done some plotting, Let's go ahead and find correlation between all the stocks.
#
# In order to find show correlation betwwen all the stocks we can simply use pair plot on our dataframes of all companies.

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis of all the comparisons

s.pairplot(tech_returns.dropna(),size=3)

# %% [markdown]
# Above we can see all the relationships on daily returns between all the stocks. A quick glance shows an interesting correlation between Google and Amazon daily returns. It might be interesting to investigate that individual comaprison. While the simplicity of just calling s.pairplot() is fantasti

# %%
# Grab all the data for the tech stock list into one DataFrame

df =dr.data.get_data_yahoo(tech_list, start, end)

# %%
#Correlation between all the stocks by hand

df.corr()
# Out:
# Attributes              High                                     Low  \
# Symbols                 AAPL      AMZN     GOOGL      MSFT      AAPL
# Attributes Symbols
# High       AAPL     1.000000  0.908889  0.872988  0.910084  0.999203
#            AMZN     0.908889  1.000000  0.962213  0.980307  0.907175
#            GOOGL    0.872988  0.962213  1.000000  0.940295  0.874112
#            MSFT     0.910084  0.980307  0.940295  1.000000  0.907889
# Low        AAPL     0.999203  0.907175  0.874112  0.907889  1.000000
#            AMZN     0.908952  0.999580  0.963400  0.979666  0.907992
#            GOOGL    0.870544  0.958851  0.999218  0.937177  0.872696
#            MSFT     0.910462  0.979842  0.941700  0.999559  0.909075
# Open       AAPL     0.999495  0.907470  0.872884  0.908362  0.999350
#            AMZN     0.908986  0.999796  0.962675  0.979872  0.907481
#            GOOGL    0.871789  0.960702  0.999513  0.938788  0.873232
# ...
